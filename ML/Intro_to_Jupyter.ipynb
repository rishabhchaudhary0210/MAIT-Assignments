# %% [markdown]
# # Jupyter Notebook
# Useful tool for learning machine learning, data visulization, data analytics and other related tasks

# %%
2+2
# Out:
# 4

# %% [markdown]
# # Learning Md
# ### Favourite Programming Languages
#
# - C++
# - Javascript
# - Python

# %%
def factorial(n):
  if n == 1:
    return 1
  return n * factorial(n-1)

# %%
print(f"Factorial of 5 = {factorial(5)}")
print(f"Factorial of 9 = {factorial(9)}")
# Out:
# Factorial of 5 = 120
# Factorial of 9 = 362880

# %%
import numpy as np

data = [3,5,8,9,11,25,28,76,100,340,756]
mean_value = np.mean(data)
print(f"Mean: {mean_value}")
# Out:
# Mean: 123.72727272727273

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Line chart
plt.plot(data)
plt.title('Line Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# Histogram
sns.histplot(data, bins=5)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #

# %%
# !pip install ipywidgets
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
import ipywidgets as widgets
from IPython.display import display

# Create a slider widget
slider = widgets.IntSlider(value=1, min=1, max=10, step=1, description='Number:')
display(slider)
# Out:
# IntSlider(value=1, description='Number:', max=10, min=1)

# %%
def update_plot(input):
    plt.clf()  # Clear the current figure
    x = np.linspace(0, 10, 100)
    y = np.sin(x) * input
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Interactive Plot')
    plt.show()

widgets.interactive(update_plot, input=slider)
# Out:
# interactive(children=(IntSlider(value=1, description='Number:', max=10, min=1), Output()), _dom_classes=('widg…
